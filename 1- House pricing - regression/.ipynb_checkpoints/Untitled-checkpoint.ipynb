# %% [markdown]
# # Import basic library and read data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('house_data.csv')
df=data.copy()
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### Handling duplicated data

# %%
df.duplicated().sum() # NO duplicated data
# Out:
# 0

# %% [markdown]
# ### Handling missing values

# %%
df.isna().sum() # NO missing values
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ### Remove unnecessary columns

# %%
print (f"waterfront:{df.waterfront.value_counts()}")
print ("-"*30)
print (f"view:{df.view.value_counts()}")
print ("-"*30)
print (f"condition:{df.condition.value_counts()}")
print ("-"*30)
print (f"yr_renovated:{df.yr_renovated.value_counts()}")
# Out:
# waterfront:waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64
# ------------------------------
# view:view
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: count, dtype: int64
# ------------------------------
# condition:condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64
# ------------------------------
# yr_renovated:yr_renovated
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %%
df.drop(columns=['id','date','waterfront','view','yr_renovated'],inplace=True)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 0  221900.0         3       1.00         1180      5650     1.0          3
# 1  538000.0         3       2.25         2570      7242     2.0          3
# 2  180000.0         2       1.00          770     10000     1.0          3
# 3  604000.0         4       3.00         1960      5000     1.0          5
# 4  510000.0         3       2.00         1680      8080     1.0          3
#
#    grade  sqft_above  sqft_basement  yr_built  zipcode      lat     long  \
# 0      7        1180              0      1955    98178  47.5112 -122.257
# 1      7        2170            400      1951    98125  47.7210 -122.319
# 2      6         770              0      1933    98028  47.7379 -122.233
# 3      7        1050            910      1965    98136  47.5208 -122.393
# 4      8        1680              0      1987    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   condition      21613 non-null  int64
#  7   grade          21613 non-null  int64
#  8   sqft_above     21613 non-null  int64
#  9   sqft_basement  21613 non-null  int64
#  10  yr_built       21613 non-null  int64
#  11  zipcode        21613 non-null  int64
#  12  lat            21613 non-null  float64
#  13  long           21613 non-null  float64
#  14  sqft_living15  21613 non-null  int64
#  15  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(11)
# memory usage: 2.6 MB

# %% [markdown]
# ### Detect & Handling outlayers

# %%
fig, axes = plt.subplots(nrows=8, ncols=2, figsize=(15, 35))  
    
for i, col in enumerate(df.columns):
    ax = axes[i // 2, i % 2]  
    sns.boxplot(data=df.iloc[:,:], x=col, ax=ax)

# %%
def handling_outlayers(df):
    for col in df.columns:
        Q1=df[col].quantile(0.25)
        Q3=df[col].quantile(0.75)
        IQR=Q3-Q1

        upper_limit=Q3+IQR*1.5
        lower_limit=Q1-IQR*1.5

        df[col]=np.where(df[col]<lower_limit,lower_limit,df[col])
        df[col]=np.where(df[col]>upper_limit,upper_limit,df[col])
    return df

df=handling_outlayers(df)

# %%
fig, axes = plt.subplots(nrows=8, ncols=2, figsize=(15, 35))  
    
for i, col in enumerate(df.columns):
    ax = axes[i // 2, i % 2]  
    sns.boxplot(data=df.iloc[:,:], x=col, ax=ax)

# %% [markdown]
# # EDA

# %%
corr=df.corr()
corr
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.352304   0.526778     0.701154  0.172300  0.298728
# bedrooms       0.352304  1.000000   0.527859     0.617376  0.194245  0.184460
# bathrooms      0.526778  0.527859   1.000000     0.746207  0.110984  0.514041
# sqft_living    0.701154  0.617376   0.746207     1.000000  0.348589  0.363894
# sqft_lot       0.172300  0.194245   0.110984     0.348589  1.000000 -0.192408
# floors         0.298728  0.184460   0.514041     0.363894 -0.192408  1.000000
# condition      0.041038  0.023746  -0.129227    -0.060316  0.067827 -0.265389
# grade          0.686612  0.376826   0.664120     0.743257  0.201319  0.477625
# sqft_above     0.602485  0.510376   0.673484     0.868912  0.320532  0.542500
# sqft_basement  0.294248  0.303125   0.259800     0.399561  0.099345 -0.256446
# yr_built       0.064247  0.170449   0.526488     0.333555  0.036435  0.489319
# zipcode       -0.043023 -0.165702  -0.210991    -0.206448 -0.286511 -0.059121
# lat            0.402520 -0.015255   0.020447     0.051304 -0.120522  0.049616
# long           0.050794  0.152064   0.240472     0.260427  0.353966  0.128346
# sqft_living15  0.626381  0.422509   0.568519     0.763878  0.391249  0.282338
# sqft_lot15     0.167144  0.183747   0.105237     0.334951  0.910903 -0.195487
#
#                condition     grade  sqft_above  sqft_basement  yr_built  \
# price           0.041038  0.686612    0.602485       0.294248  0.064247
# bedrooms        0.023746  0.376826    0.510376       0.303125  0.170449
# bathrooms      -0.129227  0.664120    0.673484       0.259800  0.526488
# sqft_living    -0.060316  0.743257    0.868912       0.399561  0.333555
# sqft_lot        0.067827  0.201319    0.320532       0.099345  0.036435
# floors         -0.265389  0.477625    0.542500      -0.256446  0.489319
# condition       1.000000 -0.152782   -0.164618       0.180211 -0.364141
# grade          -0.152782  1.000000    0.735790       0.136364  0.470996
# sqft_above     -0.164618  0.735790    1.000000      -0.092503  0.441207
# sqft_basement   0.180211  0.136364   -0.092503       1.000000 -0.144648
# yr_built       -0.364141  0.470996    0.441207      -0.144648  1.000000
# zipcode         0.003328 -0.191453   -0.271463       0.086051 -0.346869
# lat            -0.014860  0.112239   -0.006463       0.114491 -0.148123
# long           -0.107651  0.214541    0.366915      -0.157266  0.417767
# sqft_living15  -0.092840  0.698435    0.734137       0.178772  0.331623
# sqft_lot15      0.076148  0.207675    0.311740       0.088764  0.057213
#
#                 zipcode       lat      long  sqft_living15  sqft_lot15
# price         -0.043023  0.402520  0.050794       0.626381    0.167144
# bedrooms      -0.165702 -0.015255  0.152064       0.422509    0.183747
# bathrooms     -0.210991  0.020447  0.240472       0.568519    0.105237
# sqft_living   -0.206448  0.051304  0.260427       0.763878    0.334951
# sqft_lot      -0.286511 -0.120522  0.353966       0.391249    0.910903
# floors        -0.059121  0.049616  0.128346       0.282338   -0.195487
# condition      0.003328 -0.014860 -0.107651      -0.092840    0.076148
# grade         -0.191453  0.112239  0.214541       0.698435    0.207675
# sqft_above    -0.271463 -0.006463  0.366915       0.734137    0.311740
# sqft_basement  0.086051  0.114491 -0.157266       0.178772    0.088764
# yr_built      -0.346869 -0.148123  0.417767       0.331623    0.057213
# zipcode        1.000000  0.267047 -0.573090      -0.283672   -0.298259
# lat            0.267047  1.000000 -0.138735       0.048155   -0.119695
# long          -0.573090 -0.138735  1.000000       0.351330    0.364926
# sqft_living15 -0.283672  0.048155  0.351330       1.000000    0.406465
# sqft_lot15    -0.298259 -0.119695  0.364926       0.406465    1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
trival_columns=['condition','yr_built','zipcode','long']
df.drop(columns=trival_columns,inplace=True)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  grade  \
# 0  221900.0       3.0       1.00       1180.0    5650.0     1.0    7.0
# 1  538000.0       3.0       2.25       2570.0    7242.0     2.0    7.0
# 2  180000.0       2.0       1.00        770.0   10000.0     1.0    6.0
# 3  604000.0       4.0       3.00       1960.0    5000.0     1.0    7.0
# 4  510000.0       3.0       2.00       1680.0    8080.0     1.0    8.0
#
#    sqft_above  sqft_basement      lat  sqft_living15  sqft_lot15
# 0      1180.0            0.0  47.5112         1340.0      5650.0
# 1      2170.0          400.0  47.7210         1690.0      7639.0
# 2       770.0            0.0  47.7379         2720.0      8062.0
# 3      1050.0          910.0  47.5208         1360.0      5000.0
# 4      1680.0            0.0  47.6168         1800.0      7503.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  float64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  float64
#  4   sqft_lot       21613 non-null  float64
#  5   floors         21613 non-null  float64
#  6   grade          21613 non-null  float64
#  7   sqft_above     21613 non-null  float64
#  8   sqft_basement  21613 non-null  float64
#  9   lat            21613 non-null  float64
#  10  sqft_living15  21613 non-null  float64
#  11  sqft_lot15     21613 non-null  float64
# dtypes: float64(12)
# memory usage: 2.0 MB

# %%
plt.scatter(x=df.sqft_living,y=df.price)

# %%
important_features=['sqft_living','grade','sqft_above','sqft_living15']

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,10))  
    
for i, col in enumerate(important_features):
    ax = axes[i // 2, i % 2]  
    ax.scatter(df[col], df['price'])
    ax.set_title(f'Scatter plot of {col} vs price')
    ax.set_xlabel(col)
    ax.set_ylabel('price')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Split data

# %%
x=df.drop(columns=['price'])
y=df['price']
print (x.shape)
print (y.shape)
# Out:
# (21613, 11)
# (21613,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print (f'x_train shape : {x_train.shape}')
print (f'y_train shape : {y_train.shape}')
print (f'x_test shape : {x_test.shape}')
print (f'y_test shape : {y_test.shape}')
# Out:
# x_train shape : (15129, 11)
# y_train shape : (15129,)
# x_test shape : (6484, 11)
# y_test shape : (6484,)

# %% [markdown]
# ### Data Scalling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %% [markdown]
# # Model

# %% [markdown]
# ### Simple linear regression

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(x_train,y_train)
preds=model.predict(x_test)

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

print (f"mae = {mean_absolute_error(y_test,preds)}")
print (f"mse = {mean_squared_error(y_test,preds)}")
print (f"r2 score = {r2_score(y_test,preds)}")
# Out:
# mae = 108433.3211276731
# mse = 20415430319.68673
# r2 score = 0.6781487438082132

# %% [markdown]
# ### polynomial linear regression

# %%
from sklearn.preprocessing import PolynomialFeatures

for d in range(2,5):
    # polynomial features
    poly=PolynomialFeatures(d)
    x_poly=poly.fit_transform(x)
    # scalling x
    x_scaled=scaler.fit_transform(x_poly)
    # split data
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,random_state=42)
    # build model
    model.fit(x_train,y_train)
    train_pred=model.predict(x_train)
    print ("degree =",d)
    print ("For training:")
    print(f"mse: {mean_squared_error(y_train, train_pred)}, mae: {mean_absolute_error(y_train, train_pred)}, r2: {r2_score(y_train, train_pred)}")
    test_pred=model.predict(x_test)
    print ("For testing:")
    print(f"mse: {mean_squared_error(y_test, test_pred)}, mae: {mean_absolute_error(y_test, test_pred)}, r2: {r2_score(y_test, test_pred)}")
# Out:
# degree = 2
# For training:
# mse: 14912459679.817205, mae: 90834.86461344127, r2: 0.7598385463803948
# For testing:
# mse: 15825727208.186394, mae: 92873.23360458307, r2: 0.7505058623627636
# degree = 3
# For training:
# mse: 11113772135.412292, mae: 76831.38678641824, r2: 0.8210154643468986
# For testing:
# mse: 12592914846.138384, mae: 81031.26257875263, r2: 0.8014714655102095
# degree = 4
# For training:
# mse: 8904760966.895094, mae: 68151.59065143792, r2: 0.8565910397170066
# For testing:
# mse: 21581669695.780018, mae: 87133.94568223722, r2: 0.6597628659531679

# %%
poly=PolynomialFeatures(3)
x_poly=poly.fit_transform(x)
# scalling x
x_scaled=scaler.fit_transform(x_poly)
# split data
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,random_state=42)
# build model
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
preds=model.predict(x_test)
print(f"mse: {mean_squared_error(y_test, preds)}, mae: {mean_absolute_error(y_test, preds)}, r2: {r2_score(y_test, preds)}")
# Out:
# mse: 12592914846.138384, mae: 81031.26257875263, r2: 0.8014714655102095
